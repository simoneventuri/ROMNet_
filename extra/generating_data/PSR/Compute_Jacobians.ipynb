# %%
### Importing Libraries

import sys
print(sys.version)
import os
import numpy as np
import pandas as pd
import time

import matplotlib.pyplot as plt
WORKSPACE_PATH  = os.environ['WORKSPACE_PATH']
plt.style.use(WORKSPACE_PATH+'/ROMNet/romnet/extra/postprocessing/presentation.mplstyle')

OutputDir  = WORKSPACE_PATH+'/ROMNet/Data_1PSR_Clean/'
# Out:
# 3.8.9 (default, Apr  3 2021, 01:51:00)
# [Clang 12.0.0 (clang-1200.0.32.29)]

# %%
Data = pd.read_csv(OutputDir+'/orig_data/Jacobian.csv.1', header=None)
JJ   = np.abs(Data.to_numpy())

# %%
plt.plot(JJ[:,-2])
plt.yscale('log')

# %% [markdown]
# #
